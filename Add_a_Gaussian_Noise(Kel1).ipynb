# %% [markdown]
# <a href="https://colab.research.google.com/github/Firizki17/Pengolahan-Citra-Digital/blob/main/Add_a_Gaussian_Noise(Kel1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from scipy.stats.kde import gaussian_kde
import matplotlib.pyplot as plt
import urllib.request
import numpy as np

url = 'https://upload.wikimedia.org/wikipedia/en/7/7d/Lenna_%28test_image%29.png'
resp = urllib.request.urlopen(url)
image = np.asarray(bytearray(resp.read()), dtype="uint8")

f = cv2.imdecode(image, cv2.IMREAD_GRAYSCALE)
f = f / 255

plt.figure(figsize=(6,6))
plt.imshow(f, cmap='gray')
plt.title('Original Image')
plt.axis('off')
plt.show()
# Out:
# <ipython-input-2-9d9c0129196e>:3: DeprecationWarning: Please import `gaussian_kde` from the `scipy.stats` namespace; the `scipy.stats.kde` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.stats.kde import gaussian_kde

# %%
x, y = f.shape
mean = 0
var = 0.01
sigma = np.sqrt(var)
n = np.random.normal(loc=mean, scale=sigma, size=(x, y))

# Display the Gaussian noise
plt.figure(figsize=(6,6))
plt.imshow(n, cmap='gray')
plt.title('Gaussian Noise')
plt.axis('off')
plt.show()

# %%
kde = gaussian_kde(n.reshape(int(x * y)))
dist_space = np.linspace(np.min(n), np.max(n), 100)
plt.figure(figsize=(8, 4))
plt.plot(dist_space, kde(dist_space))
plt.xlabel('Noise pixel value')
plt.ylabel('Frequency')
plt.title('Probability Density Function (PDF) of Gaussian Noise')
plt.show()

# %%
g = f + n
plt.figure(figsize=(6,6))
plt.imshow(g, cmap='gray')
plt.title('Corrupted Image')
plt.axis('off')
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
axs[0].imshow(f, cmap='gray')
axs[0].set_title('Original Image')
axs[0].axis('off')

axs[1].imshow(n, cmap='gray')
axs[1].set_title('Gaussian Noise')
axs[1].axis('off')

axs[2].imshow(g, cmap='gray')
axs[2].set_title('Corrupted Image')
axs[2].axis('off')

plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 5))

# Histogram for original image
axs[0].hist(f.ravel(), bins=50, color='blue', alpha=0.7)
axs[0].set_title('Original Image Histogram')
axs[0].set_xlabel('Pixel Intensity')
axs[0].set_ylabel('Frequency')

# Histogram for Gaussian noise
axs[1].hist(n.ravel(), bins=50, color='red', alpha=0.7)
axs[1].set_title('Gaussian Noise Histogram')
axs[1].set_xlabel('Pixel Intensity')
axs[1].set_ylabel('Frequency')

# Histogram for corrupted image
axs[2].hist(g.ravel(), bins=50, color='purple', alpha=0.7)
axs[2].set_title('Corrupted Image Histogram')
axs[2].set_xlabel('Pixel Intensity')
axs[2].set_ylabel('Frequency')

plt.show()
